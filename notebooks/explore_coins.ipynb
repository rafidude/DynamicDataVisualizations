# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfw = pd.read_csv("./data/BTCUSD_1W.csv", parse_dates=["time"], index_col="time")

# %%
dfw['multiple'] = dfw['close']/3200
# Out:
#                              open    high     low   close         Volume  \
# time
# 2016-01-11 00:00:00+00:00  448.20  451.13  352.00  380.16  100170.199579
# 2016-01-18 00:00:00+00:00  379.94  422.98  372.53  402.16   76684.601573
# 2016-01-25 00:00:00+00:00  402.16  402.31  363.73  368.49   50604.935446
# 2016-02-01 00:00:00+00:00  368.49  391.88  365.00  375.00   49519.037798
# 2016-02-08 00:00:00+00:00  375.00  406.71  369.12  405.00   53282.386439
#
#                                Volume MA
# time
# 2016-01-11 00:00:00+00:00  138565.906516
# 2016-01-18 00:00:00+00:00  135032.536595
# 2016-01-25 00:00:00+00:00  130491.283367
# 2016-02-01 00:00:00+00:00  127439.485257
# 2016-02-08 00:00:00+00:00  123801.216150

# %%
dfw["2016-04"].close.mean()
# Out:
# 439.7

# %%
dfw.close.resample('M').mean()
# Out:
# time
# 2016-01-31 00:00:00+00:00      383.603333
# 2016-02-29 00:00:00+00:00      411.282000
# 2016-03-31 00:00:00+00:00      415.017500
# 2016-04-30 00:00:00+00:00      439.700000
# 2016-05-31 00:00:00+00:00      489.264000
#                                  ...
# 2021-06-30 00:00:00+00:00    36148.060000
# 2021-07-31 00:00:00+00:00    35325.615000
# 2021-08-31 00:00:00+00:00    48161.316000
# 2021-09-30 00:00:00+00:00    46180.227500
# 2021-10-31 00:00:00+00:00    55063.300000
# Freq: M, Name: close, Length: 70, dtype: float64

# %%
dfw["2018-12":"2019-03"].close.resample('W').mean().plot(kind="line")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
dfw["2018-12":"2019-03"].close.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
dfw[].close.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
dfw["2016-01":"2017-02"].close.plot()
# Out:
# <AxesSubplot:xlabel='time'>
